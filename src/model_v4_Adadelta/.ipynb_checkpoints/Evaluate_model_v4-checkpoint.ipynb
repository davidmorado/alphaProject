# %%
#%qtconsole
import pickle 
import os
import matplotlib.pyplot as plt

# %%
filelist = os.listdir('gridresults/')

# %%
results = []
for filename in os.listdir("gridresults/"):
    with open("gridresults/" + filename, 'rb') as f:
        results.append(pickle.load(f))
        bw = 
        hp_dict = {
            
        }

# %% [markdown]
# ### Plot validation accuracies

# %%
fig1 = plt.figure(figsize=(16, 8))
ax1 = fig1.add_subplot(111)
for i in range(len(results)):
        ax1.plot(range(len(results[i][0])), results[i][0], alpha=0.9)
plt.show()

# %% [markdown]
# Notes:
# - All the best models run out the whole 500 epochs.
# - At 450 epochs, one model makes a large dip in accuracy (but Early Stopping did not act)

# %% [markdown]
# ### Find optimal hyperparameter configuration

# %%
best_val_acc_index = 0
best_val_acc = 0
for i in range(len(results)):
    if results[i][0][-1] > best_val_acc:
        best_val_acc_index = i
        best_val_acc = results[i][0][-1]
print(best_val_acc_index)
print(best_val_acc)
print(filelist[best_val_acc_index])
# Out:
# 157
# 0.8045
# Adadelta_bw=10.0_kpc=1000_es=300_tp=1.0.pkl

# %% [markdown]
# Notes:
# - Embedding size seems to be absolutely crucial to model performance (see failing hyperparameter combinations below)
# - By accident tried out [300, 30, 3] instead of [3000, 300, 30] in this grid search

# %% [markdown]
# ### Find failing hyperparameter configurations

# %%
for i in range(len(results)):
    if results[i][0][-1] == 0.10:
        print(filelist[i])
# we observe that embedding size = 3 is too small to make any meaningful predictions i.e. the validation accuracy
# stays at 10% which means the model is not learning anything
# Out:
# Adadelta_bw=100.0_kpc=10_es=3_tp=0.25.pkl
# Adadelta_bw=10.0_kpc=1000_es=3_tp=0.25.pkl
# Adadelta_bw=0.01_kpc=1000_es=3_tp=0.25.pkl
# Adadelta_bw=10.0_kpc=1000_es=3_tp=0.5.pkl
# Adadelta_bw=100.0_kpc=1000_es=3_tp=0.125.pkl
# Adadelta_bw=1.0_kpc=1000_es=3_tp=1.0.pkl
# Adadelta_bw=10.0_kpc=10_es=3_tp=1.0.pkl
# Adadelta_bw=0.01_kpc=10_es=3_tp=0.25.pkl
# Adadelta_bw=0.1_kpc=1000_es=3_tp=1.0.pkl
# Adadelta_bw=0.1_kpc=1000_es=3_tp=0.125.pkl
# Adadelta_bw=10.0_kpc=1000_es=3_tp=0.125.pkl
# Adadelta_bw=1.0_kpc=1000_es=3_tp=0.5.pkl
# Adadelta_bw=0.1_kpc=10_es=3_tp=0.25.pkl
# Adadelta_bw=0.01_kpc=100_es=3_tp=0.25.pkl
# Adadelta_bw=10.0_kpc=1000_es=3_tp=1.0.pkl
# Adadelta_bw=0.1_kpc=1000_es=3_tp=0.5.pkl
# Adadelta_bw=1.0_kpc=100_es=3_tp=0.125.pkl
# Adadelta_bw=10.0_kpc=10_es=3_tp=0.125.pkl
# Adadelta_bw=0.01_kpc=1000_es=3_tp=0.125.pkl
# Adadelta_bw=0.1_kpc=1000_es=3_tp=0.25.pkl
# Adadelta_bw=0.1_kpc=1_es=3_tp=0.25.pkl
# Adadelta_bw=0.1_kpc=100_es=3_tp=0.25.pkl
# Adadelta_bw=0.01_kpc=100_es=3_tp=1.0.pkl
# Adadelta_bw=1.0_kpc=100_es=3_tp=0.25.pkl
# Adadelta_bw=0.01_kpc=1000_es=3_tp=0.5.pkl
# Adadelta_bw=0.1_kpc=100_es=3_tp=0.5.pkl
# Adadelta_bw=100.0_kpc=1000_es=3_tp=0.25.pkl
# Adadelta_bw=100.0_kpc=1000_es=3_tp=1.0.pkl
# Adadelta_bw=1.0_kpc=100_es=3_tp=1.0.pkl
# Adadelta_bw=0.01_kpc=100_es=3_tp=0.125.pkl
# Adadelta_bw=10.0_kpc=100_es=3_tp=0.5.pkl
# Adadelta_bw=1.0_kpc=1000_es=3_tp=0.125.pkl
# Adadelta_bw=1.0_kpc=100_es=3_tp=0.5.pkl
# Adadelta_bw=100.0_kpc=100_es=3_tp=0.5.pkl
# Adadelta_bw=10.0_kpc=100_es=3_tp=1.0.pkl
# Adadelta_bw=1.0_kpc=1000_es=3_tp=0.25.pkl
# Adadelta_bw=0.01_kpc=100_es=3_tp=0.5.pkl
# Adadelta_bw=10.0_kpc=100_es=3_tp=0.25.pkl
# Adadelta_bw=0.01_kpc=1000_es=3_tp=1.0.pkl
# Adadelta_bw=0.1_kpc=100_es=3_tp=1.0.pkl
# Adadelta_bw=0.1_kpc=100_es=3_tp=0.125.pkl
# Adadelta_bw=100.0_kpc=1000_es=3_tp=0.5.pkl

# %% [markdown]
# Next steps:
# - Rerun code with embedding size = 100
# - Rewrite Code s.t. results and hyperparameters are each one dictionary.
# - Run Model again without cache over [train_percentage, embedding_size].
# - Plot the proposed hyperparameter plots. (Ask if it makes sense to change BW to be another variable).

# %% [markdown]
# ### Plot proposed hyperparameter plots
