# %%
#%qtconsole
import pickle 
import os
import matplotlib.pyplot as plt

# %%
filelist = os.listdir('gridresults/')

# %%
results = []
for filename in os.listdir("gridresults/"):
    with open("gridresults/" + filename, 'rb') as f:
        results.append(pickle.load(f))

# %%
results[0][0][-1]
# Out:
# 0.6622

# %%
# plot validation accuracies
fig1 = plt.fig(figsize=(12, 12))
for i in range(len(results)):
        plt.plot(range(len(results[i][0])), results[i][0], alpha=0.1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-b05ec34c2538> in <module>
#       2 for i in range(len(results)):
#       3         plt.plot(range(len(results[i][0])), results[i][0], alpha=0.1)
# ----> 4 plt.show(figsize=(12, 12))
#
# ~/anaconda3/envs/studyenv/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# TypeError: show() got an unexpected keyword argument 'figsize'

# %%
best_val_acc_index = 0
best_val_acc = 0
for i in range(len(results)):
    if results[i][0][-1] > best_val_acc:
        best_val_acc_index = i
        best_val_acc = results[i][0][-1]
print(best_val_acc_index)
print(best_val_acc)
print(filelist[157])
# Out:
# 157
# 0.8045
# Adadelta_bw=10.0_kpc=1000_es=300_tp=1.0.pkl
